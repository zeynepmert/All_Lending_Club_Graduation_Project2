# %% [markdown]
# # Accepted to Credit History

# %%
import pandas as pd

# %%
df_accepted = pd.read_csv('../../data/accepted_2007_to_2018Q4.csv')
display(df_accepted.head())
# Out:
# C:\Users\zeynep\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (0,19,49,59,118,129,130,131,134,135,136,139,145,146,147) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#          id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  68407277        NaN     3600.0       3600.0           3600.0   36 months
# 1  68355089        NaN    24700.0      24700.0          24700.0   36 months
# 2  68341763        NaN    20000.0      20000.0          20000.0   60 months
# 3  66310712        NaN    35000.0      35000.0          35000.0   60 months
# 4  68476807        NaN    10400.0      10400.0          10400.0   60 months
#
#    int_rate  installment grade sub_grade  ... hardship_payoff_balance_amount  \
# 0     13.99       123.03     C        C4  ...                            NaN
# ...

# %%
df_accepted.filter(like='mort_acc').columns
# Out:
# Index(['mort_acc', 'sec_app_mort_acc'], dtype='object')

# %%
pd.set_option('display.max_columns', None)
print(df_accepted.columns.tolist())
# Out:
# ['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term', 'int_rate', 'installment', 'grade', 'sub_grade', 'emp_title', 'emp_length', 'home_ownership', 'annual_inc', 'verification_status', 'issue_d', 'loan_status', 'pymnt_plan', 'url', 'desc', 'purpose', 'title', 'zip_code', 'addr_state', 'dti', 'delinq_2yrs', 'earliest_cr_line', 'fico_range_low', 'fico_range_high', 'inq_last_6mths', 'mths_since_last_delinq', 'mths_since_last_record', 'open_acc', 'pub_rec', 'revol_bal', 'revol_util', 'total_acc', 'initial_list_status', 'out_prncp', 'out_prncp_inv', 'total_pymnt', 'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int', 'total_rec_late_fee', 'recoveries', 'collection_recovery_fee', 'last_pymnt_d', 'last_pymnt_amnt', 'next_pymnt_d', 'last_credit_pull_d', 'last_fico_range_high', 'last_fico_range_low', 'collections_12_mths_ex_med', 'mths_since_last_major_derog', 'policy_code', 'application_type', 'annual_inc_joint', 'dti_joint', 'verification_status_joint', 'acc_now_delinq
# ...

# %%
# id is pk ?
is_id_unique = df_accepted['id'].is_unique
print(f"Is the 'id' column in df_accepted unique? {is_id_unique}")
# Out:
# Is the 'id' column in df_accepted unique? True

# %%
null_ids = df_accepted['id'].isnull().sum()
print(f"Number of null values in 'id' column: {null_ids}")
# Out:
# Number of null values in 'id' column: 0

# %%
df_accepted['id'].shape[0]
# Out:
# 2260701

# %%
print("Checking for columns where all values are null in df_accepted...")
null_columns_all = df_accepted.columns[df_accepted.isnull().all()].tolist()

if null_columns_all:
    print("Columns where all values are null:")
    for col in null_columns_all:
        print(f"- {col}")
else:
    print("No columns found where all values are null.")
# Out:
# Checking for columns where all values are null in df_accepted...
# Columns where all values are null:
# - member_id

# %%
selected_columns = [
    'id',
    'earliest_cr_line',
    'fico_range_low',
    'fico_range_high',
    'last_fico_range_low',
    'last_fico_range_high',
    'inq_last_6mths',
    'inq_last_12m',
    'inq_fi',
    'total_cu_tl',
    'acc_open_past_24mths',
    'open_acc',
    'pub_rec',
    'revol_bal',
    'revol_util',
    'total_acc',
    'avg_cur_bal',
    'bc_open_to_buy',
    'bc_util',
    'mort_acc',
    'tot_coll_amt',
    'tot_cur_bal',
    'total_rev_hi_lim',
    'total_bc_limit',
    'total_il_high_credit_limit',
    'all_util',
    'max_bal_bc',
    'num_actv_bc_tl',
    'num_actv_rev_tl',
    'num_bc_sats',
    'num_bc_tl',
    'num_il_tl',
    'num_op_rev_tl',
    'num_rev_accts',
    'num_rev_tl_bal_gt_0',
    'num_sats',
    'mo_sin_old_il_acct',
    'mo_sin_old_rev_tl_op',
    'mo_sin_rcnt_rev_tl_op',
    'mo_sin_rcnt_tl',
    'mort_acc',
    'pct_tl_nvr_dlq',
    'percent_bc_gt_75'
]

credit_history = df_accepted[selected_columns].copy()
display(credit_history.head())
credit_history.shape
credit_history.to_csv('credit_history.csv', index=False)
# Out:
#          id earliest_cr_line  fico_range_low  fico_range_high  \
# 0  68407277         Aug-2003           675.0            679.0
# 1  68355089         Dec-1999           715.0            719.0
# 2  68341763         Aug-2000           695.0            699.0
# 3  66310712         Sep-2008           785.0            789.0
# 4  68476807         Jun-1998           695.0            699.0
#
#    last_fico_range_low  last_fico_range_high  inq_last_6mths  inq_last_12m  \
# 0                560.0                 564.0             1.0           4.0
# 1                695.0                 699.0             4.0           6.0
# 2                700.0                 704.0             0.0           1.0
# 3                675.0                 679.0             0.0           0.0
# 4                700.0                 704.0             3.0           3.0
#
#    inq_fi  total_cu_tl  acc_open_past_24mths  open_acc  pub_rec  revol_bal  \
# ...

# %%
df_credit_history = pd.read_csv('../../data/created_data/credit_history.csv')
display(df_credit_history.head())
# Out:
# C:\Users\zeynep\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#          id earliest_cr_line  fico_range_low  fico_range_high  \
# 0  68407277         Aug-2003           675.0            679.0
# 1  68355089         Dec-1999           715.0            719.0
# 2  68341763         Aug-2000           695.0            699.0
# 3  66310712         Sep-2008           785.0            789.0
# 4  68476807         Jun-1998           695.0            699.0
#
#    last_fico_range_low  last_fico_range_high  inq_last_6mths  inq_last_12m  \
# 0                560.0                 564.0             1.0           4.0
# 1                695.0                 699.0             4.0           6.0
# 2                700.0                 704.0             0.0           1.0
# ...

# %%
pd.set_option('display.max_columns', None)
print(df_credit_history.columns.tolist())
# Out:
# ['id', 'earliest_cr_line', 'fico_range_low', 'fico_range_high', 'last_fico_range_low', 'last_fico_range_high', 'inq_last_6mths', 'inq_last_12m', 'inq_fi', 'total_cu_tl', 'acc_open_past_24mths', 'open_acc', 'pub_rec', 'revol_bal', 'revol_util', 'total_acc', 'avg_cur_bal', 'bc_open_to_buy', 'bc_util', 'mort_acc', 'tot_coll_amt', 'tot_cur_bal', 'total_rev_hi_lim', 'total_bc_limit', 'total_il_high_credit_limit', 'all_util', 'max_bal_bc', 'num_actv_bc_tl', 'num_actv_rev_tl', 'num_bc_sats', 'num_bc_tl', 'num_il_tl', 'num_op_rev_tl', 'num_rev_accts', 'num_rev_tl_bal_gt_0', 'num_sats', 'mo_sin_old_il_acct', 'mo_sin_old_rev_tl_op', 'mo_sin_rcnt_rev_tl_op', 'mo_sin_rcnt_tl', 'mort_acc.1', 'pct_tl_nvr_dlq', 'percent_bc_gt_75']
